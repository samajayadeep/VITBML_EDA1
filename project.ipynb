# %% [markdown]
# <a href="https://colab.research.google.com/github/samajayadeep/VITBML_EDA1/blob/master/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##DATA EXPLORATION:we have imported dataset from kaggle.com(https://www.kaggle.com/lenapiter/sales-data)
# The data is about sales data of office supplier.

# %% [markdown]
# ##The variables in the Dataset are as follows:
#
# shipe mode:it describes about delivery class.
#
# **sales**:it describes about the sales of the commodity
#
# **quantity**:it tells about the quantity of items
#
# **discount**:it tells about the discount offered on the purchase.
#
# **profit**:it is the gain obtained in the sale.
#
# **segment**:It tells about the buyer.
#
# **region**:it refers place
#
# **state**:it tells in which state purchase is happend.
#
# **orderdate year**: Tells about  the year in which sales are done.
#
# **orderdate_weekday**:Day on which sale happend

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **PROCEDURE:
# 1. collection of datasets from kaggle.
# 2. created a data frame using pandas
# 3. data is manipulated by removing the null values using dropna()
# 4. data description was given using describe method
# 5. the data set is visualized by using various libraries such as matplotlib and seaborn**

# %%
a=pd.read_csv('/content/data_p.csv')
a
# Out:
#        Unnamed: 0        shipmode  ...  shipdate_year  preparationtime
# 0               1     First Class  ...           2016                2
# 1               2  Standard Class  ...           2014                4
# 2               3        Same Day  ...           2013                0
# 3               4     First Class  ...           2015                1
# 4               5  Standard Class  ...           2014                7
# ...           ...             ...  ...            ...              ...
# 9997         9998     First Class  ...           2016                2
# 9998         9999  Standard Class  ...           2015                7
# 9999        10000  Standard Class  ...           2015                4
# 10000       10001  Standard Class  ...           2014                4
# 10001       10002  Standard Class  ...           2016                4
#
# [10002 rows x 20 columns]

# %%
a.isna().sum()
# Out:
# Unnamed: 0           0
# shipmode             0
# sales                0
# quantity             0
# discount             1
# profit               0
# segment              1
# region               0
# state                0
# subcategory          1
# category             0
# orderdate_day        0
# orderdate_weekday    1
# orderdate_month      0
# orderdate_year       0
# shipdate_day         0
# shipdate_weekday     0
# shipdate_month       0
# shipdate_year        0
# preparationtime      0
# dtype: int64

# %%
a.dropna(axis=0,inplace=True)
a
# Out:
#        Unnamed: 0        shipmode  ...  shipdate_year  preparationtime
# 0               1     First Class  ...           2016                2
# 1               2  Standard Class  ...           2014                4
# 2               3        Same Day  ...           2013                0
# 3               4     First Class  ...           2016                1
# 4               5  Standard Class  ...           2014                7
# ...           ...             ...  ...            ...              ...
# 9997         9998     First Class  ...           2016                2
# 9998         9999  Standard Class  ...           2015                7
# 9999        10000  Standard Class  ...           2015                4
# 10000       10001  Standard Class  ...           2014                4
# 10001       10002  Standard Class  ...           2016                4
#
# [9998 rows x 20 columns]

# %%
a.isna().sum()
# Out:
# Unnamed: 0           0
# shipmode             0
# sales                0
# quantity             0
# discount             0
# profit               0
# segment              0
# region               0
# state                0
# subcategory          0
# category             0
# orderdate_day        0
# orderdate_weekday    0
# orderdate_month      0
# orderdate_year       0
# shipdate_day         0
# shipdate_weekday     0
# shipdate_month       0
# shipdate_year        0
# preparationtime      0
# dtype: int64

# %%
a.dtypes
# Out:
# Unnamed: 0             int64
# shipmode              object
# sales                float64
# quantity               int64
# discount             float64
# profit               float64
# segment               object
# region                object
# state                 object
# subcategory           object
# category              object
# orderdate_day          int64
# orderdate_weekday     object
# orderdate_month        int64
# orderdate_year         int64
# shipdate_day           int64
# shipdate_weekday      object
# shipdate_month         int64
# shipdate_year          int64
# preparationtime        int64
# dtype: object

# %%
a.mean()
# Out:
# Unnamed: 0         5003.468194
# sales               230.114507
# quantity              3.789058
# discount              0.156227
# profit               28.706607
# orderdate_day        15.602120
# orderdate_month       7.806461
# orderdate_year     2014.723745
# shipdate_day         15.831766
# shipdate_month        7.738848
# shipdate_year      2014.739548
# preparationtime       3.957992
# dtype: float64

# %%
a.median()
# Out:
# Unnamed: 0         5003.50000
# sales                54.51400
# quantity              3.00000
# discount              0.20000
# profit                8.67125
# orderdate_day        16.00000
# orderdate_month       9.00000
# orderdate_year     2015.00000
# shipdate_day         16.00000
# shipdate_month        9.00000
# shipdate_year      2015.00000
# preparationtime       4.00000
# dtype: float64

# %%
a.mode()
# Out:
#       Unnamed: 0        shipmode  ...  shipdate_year  preparationtime
# 0              1  Standard Class  ...         2016.0              4.0
# 1              2             NaN  ...            NaN              NaN
# 2              3             NaN  ...            NaN              NaN
# 3              4             NaN  ...            NaN              NaN
# 4              5             NaN  ...            NaN              NaN
# ...          ...             ...  ...            ...              ...
# 9993        9998             NaN  ...            NaN              NaN
# 9994        9999             NaN  ...            NaN              NaN
# 9995       10000             NaN  ...            NaN              NaN
# 9996       10001             NaN  ...            NaN              NaN
# 9997       10002             NaN  ...            NaN              NaN
#
# [9998 rows x 20 columns]

# %%
a.describe()
# Out:
#          Unnamed: 0         sales  ...  shipdate_year  preparationtime
# count   9998.000000   9998.000000  ...    9998.000000      9998.000000
# mean    5003.468194    230.114507  ...    2014.739548         3.957992
# std     2886.372671    623.303789  ...       1.126747         1.746869
# min        1.000000      0.444000  ...    2013.000000         0.000000
# 25%     2504.250000     17.280000  ...    2014.000000         3.000000
# 50%     5003.500000     54.514000  ...    2015.000000         4.000000
# 75%     7502.750000    209.970000  ...    2016.000000         5.000000
# max    10002.000000  22638.480000  ...    2017.000000         7.000000
#
# [8 rows x 12 columns]

# %%
a.var(ddof=1)
# Out:
# Unnamed: 0         8.331147e+06
# sales              3.885076e+05
# quantity           4.948497e+00
# discount           4.260843e-02
# profit             5.486932e+04
# orderdate_day      7.643525e+01
# orderdate_month    1.080609e+01
# orderdate_year     1.262877e+00
# shipdate_day       7.747034e+01
# shipdate_month     1.119227e+01
# shipdate_year      1.269559e+00
# preparationtime    3.051551e+00
# dtype: float64

# %%
a.std(ddof=0)
# Out:
# Unnamed: 0         2886.228320
# sales               623.272617
# quantity              2.224410
# discount              0.206408
# profit              234.230293
# orderdate_day         8.742289
# orderdate_month       3.287098
# orderdate_year        1.123722
# shipdate_day          8.801284
# shipdate_month        3.345318
# shipdate_year         1.126691
# preparationtime       1.746782
# dtype: float64

# %%
a.std(ddof=1)
# Out:
# Unnamed: 0         2886.372671
# sales               623.303789
# quantity              2.224522
# discount              0.206418
# profit              234.242008
# orderdate_day         8.742726
# orderdate_month       3.287262
# orderdate_year        1.123778
# shipdate_day          8.801724
# shipdate_month        3.345485
# shipdate_year         1.126747
# preparationtime       1.746869
# dtype: float64

# %%
a.describe()
# Out:
#          Unnamed: 0         sales  ...  shipdate_year  preparationtime
# count   9998.000000   9998.000000  ...    9998.000000      9998.000000
# mean    5003.468194    230.114507  ...    2014.739548         3.957992
# std     2886.372671    623.303789  ...       1.126747         1.746869
# min        1.000000      0.444000  ...    2013.000000         0.000000
# 25%     2504.250000     17.280000  ...    2014.000000         3.000000
# 50%     5003.500000     54.514000  ...    2015.000000         4.000000
# 75%     7502.750000    209.970000  ...    2016.000000         5.000000
# max    10002.000000  22638.480000  ...    2017.000000         7.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# ##Gives the data about sales in respective year

# %%
s=a['sales']
j=a['orderdate_year']
plt.scatter(j,s,label='sales',color="red")
plt.ylabel('sales')
plt.xlabel('year')
plt.show()

# %% [markdown]
# ##This histogram plot tells that the profit is almost zero for most of the sales.

# %%
plt.figure(figsize=(10,7))
f=a['profit']
plt.hist(f,bins=20,color="green")
plt.title("profit");

# %% [markdown]
# ##This historgram plot gives the quantity sold in the sales.

# %%
plt.figure(figsize=(10,7))
f=a['quantity']
plt.hist(f,bins=20,color="pink")
plt.title('quantity of sales')
# Out:
# Text(0.5, 1.0, 'quantity of sales')

# %% [markdown]
# ##This histogram plot gives in which more no.of sales are done.

# %%
plt.figure(figsize=(10,7))
f=a['orderdate_year']
plt.hist(f,bins=10,color="blue")
plt.title('sales in year')
# Out:
# Text(0.5, 1.0, 'sales in year')

# %% [markdown]
# The plot gives which year has more sales

# %% [markdown]
# ##This histogram plot tells about the range of discount.

# %%
plt.figure(figsize=(10,7))
f=a['discount']
plt.hist(f,bins=10,color="orange")
plt.title('discount');

# %% [markdown]
# The plot  gives

# %% [markdown]
# ##This boxplot gives the ditribution of quantity sold in the respective years.
# *outliers are represnted by dots,they range from 10-14*

# %%
import seaborn as sns
ax = sns.boxplot(x="orderdate_year",y='quantity', data=a)
ax.set_title("boxplot")
plt.show()

# %% [markdown]
# ##This piechart tells in which year more quantity is sold.
# *As data is large we plotted for only five rows*

# %%
s=a['orderdate_year'].head()
plt.pie(d,labels=a['orderdate_year'].head(),startangle=90,autopct='%1.1f%%')
plt.show()

# %%
sns.pairplot(a,hue="orderdate_day",kind="scatter")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x="orderdate_weekday",y="sales",hue="subcategory",data=a,palette="muted")

# %% [markdown]
# ##strip plot gives the sales in the days of the week
# days are in german language

# %%
sns.stripplot(x="shipdate_weekday",y="profit",data=a)

# %% [markdown]
# Using the data given answer the following questions.
# ##1.In which year the quantity of the products sold is maximum?
# Ans:-2016
# ##2. To analyse the data what types of plot are being used?
# ans: Histogram,barplot,piechart boxplot,pair wise plot,scatter plot.
# ##3. After absorbing above piechart what conculsions can you make?
# Ans: More sales were recorded in the year 2016
# ##4. To analyse the categorical data what type of plot is used?
# Ans: bar plot
# ## 5. what is the relation between sales and year?
# Ans: increase in sales
# ## 6.The data points which are present outside the box plot are called?
# Ans: outliers
# ## 7. what type of data does this data set contain?
# Ans: categorical data
# ## 8. what type of plots are used to show the relation between two variables in general?
# Ans. scatter plot
# ## 9. what methods are used to remove the missing values?
# Ans. fillna()
#     dropna()

# %% [markdown]
# **TEAM NAME: WARRIORS
# **MEMBERS:P.S.SANTOSH KUMAR(19PA1A05C9),P.LOKESH(19PA1A05E3),RAZA ABBAS(19PA1A05F7),S.JAYADEEPU(19PA1A05G1)
# CONCLUSION: DATA ANALYSIS USING LIBRARIES SUCH AS NUMPY,PANDAS ALONG WITH DATA VISUALIZATION SUCH AS MATPLOTLIB AND SEABORN WERE IMPLEMENTED.
